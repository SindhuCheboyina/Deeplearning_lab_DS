# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
# !pip instal tensorflow_gpu
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
# !pip install tensorflow_gpu
# Out:
# ...
#      |████████████████████████████████| 320.4MB 55kB/s
# ...
